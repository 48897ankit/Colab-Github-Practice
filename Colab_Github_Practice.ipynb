# %% [markdown]
# <a href="https://colab.research.google.com/github/48897ankit/Colab-Github-Practice/blob/main/Colab_Github_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('One')
# Out:
# One
